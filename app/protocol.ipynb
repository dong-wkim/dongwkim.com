# %%
import ipywidgets as widgets
from IPython.display import display
from ipywidgets import AppLayout, Tab, Accordion, Layout, VBox, HBox, Box

app_layout = AppLayout()
tab = Tab()
accordion = Accordion()
